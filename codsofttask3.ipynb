# %% [markdown]
# <a href="https://colab.research.google.com/github/Sunilkumar414674/CODSOFTtask3/blob/main/codsofttask3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# import the Iris flower dataset
import pandas as pd
import numpy as np
iris = load_iris()
flower = pd.read_csv('/content/codsofttask3.csv')
flower
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
flower.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# to know about the flower dataset
flower.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# checking the missing values in data set
flower.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns
# HISTOGRAM
# to illustrate the distribution of each feature in the Iris dataset
flower.hist(bins=20, figsize=(12, 8),color='green')
plt.suptitle('Histograms of Features')
plt.show()

# %% [markdown]
# **1.Sepal Length**
#
#   a. Range: The sepal length values range from about 4.5 cm to 8 cm.
#
#   b. Distribution: The distribution peaks around 5.0 cm, 5.5 cm, 6.0 cm, and 6.5 cm.
#
# **2.Sepal Width**
#
#   a. Range: The sepal width values range from about 2.0 cm to 4.5 cm.
#
#   b. Distribution: The distribution is slightly skewed to the left with a peak around 3.0 cm. There are also smaller peaks around 2.5 cm and 3.5 cm.
#
# **3.Petal Length**
#
#   a. Range: The petal length values range from about 1.0 cm to 7.0 cm.
#
#   b. Distribution: The distribution  peak at around 1.5 cm and smaller peaks around 4.5 cm, 5.0 cm, and 6.0 cm.
#
# **4.Petal Width**
#
#   a. Range: The petal width values range from about 0.0 cm to 2.5 cm.
#
#   b. Distribution: The distribution peak at around 0.2 cm, another peak at 1.2 cm, and smaller peaks around 1.5 cm and 2.0 cm.

# %%
#VIOLIN PLOT
# to observe the distribution of flower data we will use violin plot
# Violin plot for each feature
plt.figure(figsize=(8, 4))
sns.violinplot(x='species', y='sepal_length', data=flower,color='yellow')
plt.title('Sepal Length Violin Plot')
plt.show()

sns.violinplot(x='species', y='sepal_width', data=flower,color='orange')
plt.title('Sepal Width Violin Plot')
plt.show()

sns.violinplot(x='species', y='petal_length', data=flower,color='violet')
plt.title('Petal Length Violin Plot')
plt.show()

sns.violinplot(x='species', y='petal_width', data=flower,color='purple')
plt.title('Petal Width Violin Plot')
plt.show()

# %% [markdown]
# **1.Sepal Length**
#
#   a. Iris-setosa :The density is fairly symmetrical around the median.
#
#   b. Iris-versicolor :The distribution shows a peak around the median but has a relatively symmetrical spread.
#
#   c. Iris-virginica :The distribution is somewhat symmetrical around the median but with slightly more density towards the higher values.
#
#   **2.sepal width**
#
#   a. Iris-setosa has a broader range and higher average sepal width compared to the other two species.
#
#   b. Iris-versicolor and Iris-virginica have more similar and narrower distributions, but Iris-virginica has a slightly higher median sepal width.
#
#   **3.petal length**
#
#    a.Iris-setosa has a very narrow range and the smallest petal length.
#
#    b.Iris-versicolor has a moderately wide range with intermediate petal length.
#
#    c.Iris-virginica has the widest range and the longest petal length.
#
#   **4.petal width**
#
#    a.Iris-setosa has the smallest petal width among the three species.
#
#    b.Iris-virginica has the largest petal.
#
#    c.Iris-versicolor is intermediate petal.

# %%
#PAIR PLOT
# to Visualize the data and to check if there are any patterns that can help in classification we will use pair plot
sns.pairplot(flower , hue='species', markers=["o", "s", "D"])
# o (circle) for setosa, s (square) for versicolor, D (diamond) for virginica
plt.show()

# %% [markdown]
# **1.Sepal Length and Sepal Width**:
#
#   a. Setosa : Setosa is clearly distinguishable from the other two species based on sepal width and sepal length.
#
#   b. Versicolor and Virginica : There is some overlap between versicolor and virginica, but versicolor tends to have lower sepal length and sepal width values compared to virginica.
#
#  **2.Petal Length and Petal Width**:
#
#   a. Setosa :It has much smaller petal lengths and widths.
#
#   b. Versicolor and Virginica : There is some overlap between versicolor and virginica, but virginica generally has higher petal length and petal width values compared to versicolor.
#
# **3.Mixed Features:**
#
#   a. Setosa : Easily separable from the other two species in most combinations of features.
#
#   b. Versicolor and Virginica : virginica tends to have higher petal length and petal width values than versicolor.

# %%
# Data Preprocessing
# for Data Preprocessing we will splitting the iris data set into training and test sets, and standardizing the feature values.
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Splitting the  iris data into features (flower_X) and target (flower_Y)
flower_X= flower.drop(columns=['species'])
flower_Y = flower['species']

# Split the iris data  into training and test sets
flowerX_train, flowerX_test, flowerY_train, flowerY_test = train_test_split(flower_X,flower_Y , test_size=0.2, random_state=42)

# %%
#  to Standardize the iris data feature values
scaler = StandardScaler()
flowerX_train = scaler.fit_transform(flowerX_train)
flowerX_train
flowerX_test = scaler.transform(flowerX_test)
flowerX_test
# Out:
# array([[ 0.35451684, -0.57925837,  0.5576453 ,  0.02332414],
#        [-0.13307079,  1.67028869, -1.16259727, -1.17620281],
#        [ 2.30486738, -1.02916778,  1.81915651,  1.48941263],
#        [ 0.23261993, -0.35430366,  0.44296246,  0.42316645],
#        [ 1.2077952 , -0.57925837,  0.61498672,  0.28988568],
#        [-0.49876152,  0.77046987, -1.27728011, -1.04292204],
#        [-0.2549677 , -0.35430366, -0.07311031,  0.15660491],
#        [ 1.32969211,  0.09560575,  0.78701097,  1.48941263],
#        [ 0.47641375, -1.9289866 ,  0.44296246,  0.42316645],
#        [-0.01117388, -0.80421307,  0.09891395,  0.02332414],
#        [ 0.84210448,  0.32056046,  0.78701097,  1.08957031],
#        [-1.23014297, -0.12934896, -1.33462153, -1.44276436],
#        [-0.37686461,  0.99542457, -1.39196294, -1.30948358],
#        [-1.10824606,  0.09560575, -1.27728011, -1.44276436],
#        [-0.86445224,  1.67028869, -1.27728011, -1.17620281],
# ...

# %%
# KNN classifier
#to make classifications about grouping of an inidvidual
from sklearn.neighbors import KNeighborsClassifier

a= KNeighborsClassifier(n_neighbors=5)
a

# Train the model
a.fit(flowerX_train, flowerY_train)
# Out:
# KNeighborsClassifier()

# %%
# to Make predictions on the iris data test set
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
# Make predictions on the test set
flower_y_pred = a.predict(flowerX_test)

# Evaluate the model
accuracy = accuracy_score(flowerY_test,flower_y_pred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 1.00

# %% [markdown]
# An accuracy of 1.00 means that the model being evaluated has achieved perfect accuracy on the iris dataset.

# %%
 #to get Classification Report on the iris data test set
print('Classification Report:')
print(classification_report(flowerY_test, flower_y_pred, target_names=iris.target_names))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        10
#   versicolor       1.00      1.00      1.00         9
#    virginica       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
#to get Confusion Matrix on the iris data test set
print('Confusion Matrix:')
conf_matrix = confusion_matrix(flowerY_test, flower_y_pred)
sns.heatmap(conf_matrix, annot=True, cmap='Blues', xticklabels=iris.target_names, yticklabels=iris.target_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# Confusion Matrix:

# %% [markdown]
# **True Positives (diagonal elements):**
#
#   a.10 instances of setosa were correctly classified as setosa.
#
#   b.9 instances of versicolor were correctly classified as versicolor.
#
#   c.11 instances of virginica were correctly classified as virginica.
#
# **True Negatives (non-diagonal elements):**
#
#   No instances of setosa, versicolor, or virginica were incorrectly classified as another class.
#
# **Overall, the confusion matrix indicates perfect classification accuracy for this model on the given test data, with all instances being correctly classified**

# %%
# to try another classification models such as Decision Trees
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn import metrics

# to  Create decision tree classifier train and predict
c= DecisionTreeClassifier()
c= c.fit(flowerX_train, flowerY_train)
flower_y_pred = c.predict(flowerX_test)

# %%
# Model accuracy
print("Accuracy:", metrics.accuracy_score(flowerY_test, flower_y_pred))

#  to Visualize the decision tree
plt.figure(figsize=(20,10))
plot_tree(c, filled=True, feature_names=iris.feature_names, class_names=iris.target_names)
plt.title('Decision Tree')
plt.show()
# Out:
# Accuracy: 1.0

# %% [markdown]
# An accuracy of 1.00 (or 100%) for a decision tree classifier indicates that the model has perfectly classified all instances in the flower iris test dataset. This means that every prediction made by the model is correct.
